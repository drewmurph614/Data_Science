# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cities_r2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 33 columns):
# name_of_city                      493 non-null object
# state_code                        493 non-null int64
# state_name                        493 non-null object
# dist_code                         493 non-null int64
# population_total                  493 non-null int64
# population_male                   493 non-null int64
# population_female                 493 non-null int64
# 0-6_population_total              493 non-null int64
# 0-6_population_male               493 non-null int64
# 0-6_population_female             493 non-null int64
# literates_total                   493 non-null int64
# literates_male                    493 non-null int64
# literates_female                  493 non-null int64
# sex_ratio                         493 non-null int64
# child_sex_ratio                   493 non-null int64
# effective_literacy_rate_total     493 non-null float64
# effective_literacy_rate_male      493 non-null float64
# effective_literacy_rate_female    493 non-null float64
# location                          493 non-null object
# total_graduates                   493 non-null int64
# male_graduates                    493 non-null int64
# female_graduates                  493 non-null int64
# Grad_%                            493 non-null float64
# M_Pop                             493 non-null float64
# F_Pop                             493 non-null float64
# Child_Pop                         493 non-null float64
# MGrad_Perc                        493 non-null float64
# FGrad_Perc                        493 non-null float64
# Literate_Perc                     493 non-null float64
# Literate_MP                       493 non-null float64
# Literate_FP                       493 non-null float64
# Literacy_Gap                      493 non-null float64
# GradGap                           493 non-null float64
# dtypes: float64(14), int64(16), object(3)
# memory usage: 127.2+ KB

# %%
print (df.describe(include=['O']))
# Out:
#        name_of_city     state_name               location
# count           493            493                    493
# unique          492             29                    490
# top     Aurangabad   UTTAR PRADESH  22.6500518,88.3423199
# freq              2             63                      2

# %%
df.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# 25%         6.041100e+04          1.363900e+04          7221.000000
# 50%         8.776800e+04          1.944000e+04         10342.000000
# 75%         1.700260e+05          3.794500e+04         19982.000000
# max         5.741632e+06          1.209275e+06        647938.000000
#
#        0-6_population_female  literates_total  literates_male  \
# count             493.000000     4.930000e+02    4.930000e+02
# mean            22243.320487     3.461527e+05    1.894384e+05
# std             49523.241379     8.220952e+05    4.534753e+05
# min              3107.000000     5.699800e+04    3.475100e+04
# 25%              6457.000000     9.768700e+04    5.357800e+04
# 50%              9172.000000     1.413290e+05    7.590600e+04
# 75%             17954.000000     2.679000e+05    1.455480e+05
# max            561337.000000     1.023759e+07    5.727774e+06
#
#        literates_female    sex_ratio  child_sex_ratio  \
# count      4.930000e+02   493.000000       493.000000
# mean       1.567143e+05   930.294118       902.332657
# std        3.690677e+05    55.849106        49.794689
# min        2.224700e+04   700.000000       762.000000
# 25%        4.391400e+04   890.000000       868.000000
# 50%        6.383600e+04   922.000000       903.000000
# 75%        1.235030e+05   971.000000       942.000000
# max        4.509812e+06  1093.000000      1185.000000
#
#        effective_literacy_rate_total  effective_literacy_rate_male  \
# count                     493.000000                    493.000000
# mean                       85.131460                     89.920162
# std                         6.186345                      5.377492
# min                        49.510000                     52.270000
# 25%                        81.750000                     87.280000
# 50%                        85.970000                     91.180000
# 75%                        89.330000                     93.400000
# max                        98.800000                     99.300000
#
#        effective_literacy_rate_female  total_graduates  male_graduates  \
# count                      493.000000     4.930000e+02    4.930000e+02
# mean                        79.967181     6.620236e+04    3.771556e+04
# std                          7.577825     1.778187e+05    9.849574e+04
# min                         46.450000     2.532000e+03    1.703000e+03
# 25%                         75.800000     1.527700e+04    9.289000e+03
# 50%                         80.920000     2.395900e+04    1.404900e+04
# 75%                         85.400000     5.036700e+04    2.787200e+04
# max                         98.310000     2.221137e+06    1.210040e+06
#
#        female_graduates
# count      4.930000e+02
# mean       2.848680e+04
# std        7.951556e+04
# min        8.290000e+02
# 25%        6.114000e+03
# 50%        9.558000e+03
# 75%        2.086600e+04
# max        1.011097e+06

# %%
df.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %%
df.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female        ...         \
# 0                 8587                   7283        ...
# 1                 6186                   5624        ...
# 2                 6731                   6372        ...
# 3                12063                  10979        ...
# 4                 9355                   9051        ...
#
#    literates_female  sex_ratio  child_sex_ratio  \
# 0             44972        890              848
# 1             43086        928              909
# 2             37660        982              947
# 3             54515        902              910
# 4             45089       1013              968
#
#    effective_literacy_rate_total  effective_literacy_rate_male  \
# 0                          79.86                         85.49
# 1                          91.99                         94.77
# 2                          80.51                         88.18
# 3                          83.46                         89.98
# 4                          68.38                         76.58
#
#    effective_literacy_rate_female               location  total_graduates  \
# 0                           73.59  30.1452928,74.1993043            16287
# 1                           89.00   21.257584,77.5086754             8863
# 2                           72.73   19.0809075,79.560344            10565
# 3                           76.23  22.7834741,86.1576889            19225
# 4                           60.33  15.6322227,77.2728368            11902
#
#   male_graduates  female_graduates
# 0           8612              7675
# 1           5269              3594
# 2           6797              3768
# 3          12189              7036
# 4           7871              4031
#
# [5 rows x 22 columns]

# %%
df['Grad_%'] = df['total_graduates']/df['population_total']

# %%
df['Grad_%'].mean()
# Out:
# 0.1323822965892236

# %%
df = df.sort_values('population_total', ascending = False)

# %%
df = df.reset_index(drop=True)

# %%
##M/F Info

# %%
gendertotal = df['population_male'].sum()/df['population_total'].sum()
MaleTotal = df['population_male'].sum()
FemaleTotal = df['population_female'].sum()

# %%
gendertotal
# Out:
# 0.522964334503896

# %%
df['M_Pop'] = df.population_male/df.population_total

# %%
df['F_Pop'] = df.population_female/df.population_total

# %%
##sorted_df = df.sort(['Ratio'], ascending = [True])

# %%
df[df['F_Pop']==df['F_Pop'].max()]
# Out:
#     name_of_city  state_code state_name  dist_code  population_total  \
# 100   Kozhikode           32     KERALA          4            432097
#
#      population_male  population_female  0-6_population_total  \
# 100           206494             225603                 41574
#
#      0-6_population_male  0-6_population_female    ...     \
# 100                21208                  20366    ...
#
#      effective_literacy_rate_total  effective_literacy_rate_male  \
# 100                           96.8                         97.93
#
#      effective_literacy_rate_female             location  total_graduates  \
# 100                           95.78  11.2587531,75.78041            61225
#
#      male_graduates  female_graduates    Grad_%     M_Pop     F_Pop
# 100           27701             33524  0.141693  0.477888  0.522112
#
# [1 rows x 25 columns]

# %%
sorted_df = df.sort_values(['M_Pop'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.tail(10).M_Pop)
plt.yticks(range(10),sorted_df.tail(10).name_of_city, fontsize = 10)
plt.plot([.5,.5],[-1,10], '--',color = 'r')
plt.title('Most Male')
plt.xlim([0,1])

plt.subplot(2,1,2)
plt.style.use('fivethirtyeight')
plt.barh(range(10),sorted_df.head(10).M_Pop)
plt.yticks(range(10),sorted_df.head(10).name_of_city, fontsize = 10)
plt.plot([.5,.5],[-1,10], '--',color = 'r')
plt.title('Most Female')
plt.xlim([0,1])
plt.xlabel('Male Population Percent by City')

# %%
sorted_df = df.sort_values(['population_total'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.tail(10).M_Pop)
plt.yticks(range(10),sorted_df.tail(10).name_of_city, fontsize = 10)
plt.plot([.5,.5],[-1,10], '--',color = 'r')
plt.title('Male Percentage in Largest Cities')
plt.xlim([0,1])
# Out:
# (0, 1)

# %%
gendertotal #Male % in India Total
# Out:
# 0.522964334503896

# %%
##Child Info

# %%
df.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates',
#        'Grad_%', 'M_Pop', 'F_Pop'],
#       dtype='object')

# %%
childtotal = df['0-6_population_male'].sum()/df['0-6_population_total'].sum()
childtotal
##India is becoming more male dominated
# Out:
# 0.5276709417079221

# %%
childs = df['0-6_population_total'].sum()/df['population_total'].sum()
childs
##10.5% of India is between 0-6
# Out:
# 0.10509160354409798

# %%
df['Child_Pop'] = df['0-6_population_total']/df.population_total

# %%
df['Child_Pop'].mean()
# Out:
# 0.10735081516027627

# %%
sorted_df = df.sort_values(['Child_Pop'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.tail(10).Child_Pop)
plt.yticks(range(10),sorted_df.tail(10).name_of_city, fontsize = 10)
plt.title('Most Children')
plt.xlim([0,.5])

plt.subplot(2,1,2)
plt.style.use('fivethirtyeight')
plt.barh(range(10),sorted_df.head(10).Child_Pop)
plt.yticks(range(10),sorted_df.head(10).name_of_city, fontsize = 10)
plt.title('Least Children')
plt.xlim([0,.5])
plt.xlabel('Child Population Percent by City')

# %%
sorted_df = df.sort_values(['population_total'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.tail(10).Child_Pop)
plt.yticks(range(10),sorted_df.tail(10).name_of_city, fontsize = 10)
plt.title('Child Percentage in Largest Cities')
plt.xlim([0,.5])
# Out:
# (0, 0.5)

# %%
sorted_df = df.sort_values(['population_total'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.head(10).Child_Pop)
plt.yticks(range(10),sorted_df.head(10).name_of_city, fontsize = 10)
plt.title('Child Percentage in Largest Cities')
plt.xlim([0,.5])
# Out:
# (0, 0.5)

# %%
df.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates',
#        'Grad_%', 'M_Pop', 'F_Pop', 'Child_Pop'],
#       dtype='object')

# %%
##Literacy

# %%
df['MGrad_Perc'] = df['male_graduates']/df.population_total 
df['FGrad_Perc'] = df['female_graduates']/df.population_total

# %%
df['Literate_Perc'] = df['literates_total']/df.population_total 
df['Literate_MP'] = df['literates_male']/df.population_male 
df['Literate_FP'] = df['literates_female']/df.population_female

# %%
df['Literacy_Gap'] = df['Literate_MP']-df['Literate_FP']

# %%
df.head()
# Out:
#          name_of_city  state_code      state_name  dist_code  \
# 0     Greater Mumbai           27     MAHARASHTRA         99
# 1              Delhi            7    NCT OF DELHI         99
# 2           Bengaluru          29       KARNATAKA         18
# 3  Greater Hyderabad           28  ANDHRA PRADESH         99
# 4          Ahmadabad           24         GUJARAT          7
#
#    population_total  population_male  population_female  0-6_population_total  \
# 0          12478447          6736815            5741632               1139146
# 1          11007835          5871362            5136473               1209275
# 2           8425970          4401299            4024671                862493
# 3           6809970          3500802            3309168                725816
# 4           5570585          2935869            2634716                589076
#
#    0-6_population_male  0-6_population_female      ...         Grad_%  \
# 0               599007                 540139      ...       0.144439
# 1               647938                 561337      ...       0.201778
# 2               444639                 417854      ...       0.188840
# 3               373794                 352022      ...       0.170948
# 4               317917                 271159      ...       0.138201
#
#       M_Pop     F_Pop  Child_Pop  MGrad_Perc  FGrad_Perc  Literate_Perc  \
# 0  0.539876  0.460124   0.091289    0.077330    0.067108       0.820421
# 1  0.533380  0.466620   0.109856    0.109925    0.091852       0.779727
# 2  0.522349  0.477651   0.102361    0.107805    0.081035       0.804174
# 3  0.514070  0.485930   0.106581    0.100647    0.070301       0.741223
# 4  0.527031  0.472969   0.105748    0.078137    0.060064       0.801406
#
#    Literate_MP Literate_FP  Literacy_Gap
# 0     0.850220    0.785458      0.064762
# 1     0.813523    0.741095      0.072428
# 2     0.832699    0.772978      0.059721
# 3     0.767856    0.713048      0.054808
# 4     0.837852    0.760795      0.077056
#
# [5 rows x 32 columns]

# %%
lit_total = df['literates_total'].sum()/df['population_total'].sum()
lit_m = df['literates_male'].sum()/df['population_male'].sum()
lit_f = df['literates_female'].sum()/df['population_female'].sum()

# %%
lit_total
# Out:
# 0.772468579038328

# %%
lit_m
# Out:
# 0.8083679786393784

# %%
lit_f
# Out:
# 0.7331128096915474

# %%
sorted_df = df.sort_values(['Literate_Perc'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.tail(10).Literate_Perc)
plt.yticks(range(10),sorted_df.tail(10).name_of_city, fontsize = 10)
plt.title('Most Literate')
plt.xlim([0,1])

plt.subplot(2,1,2)
plt.style.use('fivethirtyeight')
plt.barh(range(10),sorted_df.head(10).Literate_Perc)
plt.yticks(range(10),sorted_df.head(10).name_of_city, fontsize = 10)
plt.title('Least Literate')
plt.xlim([0,1])
plt.xlabel('Literate Population Percent by City')

# %%
sorted_df = df.sort_values(['population_total'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.tail(10).Literate_Perc)
plt.yticks(range(10),sorted_df.tail(10).name_of_city, fontsize = 10)
plt.plot([.77,.77],[-1,10], '--',color = 'g')
plt.title('Literacy Rate in Largest Cities')
plt.xlim([0,1])
# Out:
# (0, 1)

# %%
sorted_df = df.sort_values(['population_total'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.head(10).Literate_Perc)
plt.yticks(range(10),sorted_df.head(10).name_of_city, fontsize = 10)
plt.plot([.77,.77],[-1,10], '--',color = 'g')
plt.title('Literacy Rate in Smallest Cities')
plt.xlim([0,1])
# Out:
# (0, 1)

# %%
df['GradGap'] = df['MGrad_Perc']-df['FGrad_Perc']

# %%
sorted_df = df.sort_values(['GradGap'], ascending = [True])

plt.figure(figsize = (10,10))

plt.subplot(2,1,1)
plt.barh(range(10),sorted_df.tail(10).GradGap)
plt.yticks(range(10),sorted_df.tail(10).name_of_city, fontsize = 10)
plt.title('Largest Gender Graduation Gap')
plt.xlim([-.05,1])

plt.subplot(2,1,2)
plt.style.use('fivethirtyeight')
plt.barh(range(10),sorted_df.head(10).GradGap)
plt.yticks(range(10),sorted_df.head(10).name_of_city, fontsize = 10)
plt.title('Smallest Gender Graduation Gap')
plt.xlim([-.05,1])
plt.xlabel('Gender Literacy Gaps')

# %%
sns.jointplot(y='Literate_Perc',x='population_total',data=df,kind='reg', color = 'g')

# %%
df['Literacy_Gap'].mean()
# Out:
# 0.08572805727428055

# %%
df.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates',
#        'Grad_%', 'M_Pop', 'F_Pop', 'Child_Pop', 'MGrad_Perc', 'FGrad_Perc',
#        'Literate_Perc', 'Literate_MP', 'Literate_FP', 'Literacy_Gap',
#        'GradGap'],
#       dtype='object')

# %%
df[df['name_of_city']=='Hindaun ']
# Out:
#     name_of_city  state_code state_name  dist_code  population_total  \
# 461     Hindaun            8  RAJASTHAN          9            105690
#
#      population_male  population_female  0-6_population_total  \
# 461            56178              49512                 15451
#
#      0-6_population_male  0-6_population_female    ...        M_Pop     F_Pop  \
# 461                 8345                   7106    ...     0.531536  0.468464
#
#      Child_Pop  MGrad_Perc  FGrad_Perc  Literate_Perc  Literate_MP  \
# 461   0.146192    0.050062    0.025291       0.653875     0.747499
#
#      Literate_FP Literacy_Gap   GradGap
# 461     0.547645     0.199854  0.024771
#
# [1 rows x 33 columns]

# %%
df.corr().head()
# Out:
#                    state_code  dist_code  population_total  population_male  \
# state_code           1.000000  -0.088946          0.054953         0.048442
# dist_code           -0.088946   1.000000          0.318398         0.319937
# population_total     0.054953   0.318398          1.000000         0.999647
# population_male      0.048442   0.319937          0.999647         1.000000
# population_female    0.062276   0.316385          0.999547         0.998395
#
#                    population_female  0-6_population_total  \
# state_code                  0.062276              0.030726
# dist_code                   0.316385              0.318881
# population_total            0.999547              0.991590
# population_male             0.998395              0.991738
# population_female           1.000000              0.990577
#
#                    0-6_population_male  0-6_population_female  \
# state_code                    0.025069               0.037050
# dist_code                     0.318189               0.319461
# population_total              0.989977               0.992786
# population_male               0.990528               0.992482
# population_female             0.988509               0.992283
#
#                    literates_total  literates_male    ...        M_Pop  \
# state_code                0.068414        0.060318    ...    -0.638151
# dist_code                 0.315055        0.316732    ...     0.069310
# population_total          0.998777        0.998561    ...     0.129329
# population_male           0.998473        0.999003    ...     0.140764
# population_female         0.998270        0.997210    ...     0.116277
#
#                       F_Pop  Child_Pop  MGrad_Perc  FGrad_Perc  Literate_Perc  \
# state_code         0.638151  -0.402270   -0.061744   -0.069078       0.425072
# dist_code         -0.069310   0.029877    0.152976    0.099301      -0.005670
# population_total  -0.129329  -0.047837    0.114174    0.166957       0.077672
# population_male   -0.140764  -0.043389    0.110860    0.163411       0.074278
# population_female -0.116277  -0.052829    0.117828    0.170829       0.081448
#
#                    Literate_MP  Literate_FP  Literacy_Gap   GradGap
# state_code            0.440412     0.413880     -0.210346  0.001264
# dist_code            -0.011801    -0.001453     -0.016379  0.127455
# population_total      0.051990     0.091250     -0.121672 -0.073629
# population_male       0.048850     0.087468     -0.118273 -0.073854
# population_female     0.055500     0.095453     -0.125415 -0.073312
#
# [5 rows x 30 columns]

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.stripplot(y="state_name", x="population_total", data=df, jitter=True)

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.boxplot(y="state_name", x="GradGap", data=df)

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.swarmplot(y="state_name", x="GradGap", data=df)

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.stripplot(y="state_name", x="GradGap", data=df, jitter=True)

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.stripplot(y="state_name", x="Literacy_Gap", data=df, jitter=True)

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.stripplot(y="state_name", x="Literate_Perc", data=df, jitter=True)

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.stripplot(y="state_name", x="Grad_%", data=df, jitter=True)

# %%
df[df["Grad_%"]==df["Grad_%"].max()]
# Out:
#       name_of_city  state_code state_name  dist_code  population_total  \
# 318  S.A.S. Nagar            3     PUNJAB         18            146104
#
#      population_male  population_female  0-6_population_total  \
# 318            76441              69663                 13155
#
#      0-6_population_male  0-6_population_female    ...        M_Pop     F_Pop  \
# 318                 6975                   6180    ...     0.523196  0.476804
#
#      Child_Pop  MGrad_Perc  FGrad_Perc  Literate_Perc  Literate_MP  \
# 318   0.090039    0.206086    0.186258       0.848231     0.864719
#
#      Literate_FP Literacy_Gap   GradGap
# 318     0.830139      0.03458  0.019828
#
# [1 rows x 33 columns]

# %%
focus_cols = ['effective_literacy_rate_male']
df.corr().filter(focus_cols).drop(focus_cols)
# Out:
#                                 effective_literacy_rate_male
# state_code                                          0.386657
# dist_code                                          -0.003357
# population_total                                    0.039787
# population_male                                     0.037451
# population_female                                   0.042396
# 0-6_population_total                                0.016279
# 0-6_population_male                                 0.015208
# 0-6_population_female                               0.017471
# literates_total                                     0.065902
# literates_male                                      0.061108
# literates_female                                    0.071713
# sex_ratio                                           0.241332
# child_sex_ratio                                     0.071756
# effective_literacy_rate_total                       0.954109
# effective_literacy_rate_female                      0.859778
# total_graduates                                     0.066135
# male_graduates                                      0.063021
# female_graduates                                    0.069832
# Grad_%                                              0.402264
# M_Pop                                              -0.236642
# F_Pop                                               0.236642
# Child_Pop                                          -0.446162
# MGrad_Perc                                          0.381888
# FGrad_Perc                                          0.396576
# Literate_Perc                                       0.905743
# Literate_MP                                         0.957192
# Literate_FP                                         0.829015
# Literacy_Gap                                       -0.296087
# GradGap                                             0.047928

# %%
sns.distplot(df['Literate_MP'])

# %%
sns.distplot(df['Literate_FP'])

# %%
sns.distplot(df['Literate_Perc'])

# %%
sns.jointplot(y='Literate_Perc',x='Child_Pop',data=df,kind='reg', color = 'g')

# %%
sns.jointplot(y='effective_literacy_rate_male',x='F_Pop',data=df,kind='reg', color = 'g')

# %%
sns.jointplot(y='Literacy_Gap',x='GradGap',data=df,kind='reg', color = 'g')

# %%
sns.jointplot(y='effective_literacy_rate_male',x='M_Pop',data=df,kind='reg', color = 'g')

# %%
sns.jointplot(x='Literate_Perc',y='Grad_%',data=df,kind='reg', color = 'g')

# %%
df.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates',
#        'Grad_%', 'M_Pop', 'F_Pop', 'Child_Pop', 'MGrad_Perc', 'FGrad_Perc',
#        'Literate_Perc', 'Literate_MP', 'Literate_FP', 'Literacy_Gap',
#        'GradGap'],
#       dtype='object')

# %%
##Grad Rate

# %%
focus_cols = ['MGrad_Perc']
df.corr().filter(focus_cols).drop(focus_cols)
# Out:
#                                 MGrad_Perc
# state_code                       -0.061744
# dist_code                         0.152976
# population_total                  0.114174
# population_male                   0.110860
# population_female                 0.117828
# 0-6_population_total              0.094609
# 0-6_population_male               0.093619
# 0-6_population_female             0.095659
# literates_total                   0.122082
# literates_male                    0.116905
# literates_female                  0.128295
# sex_ratio                         0.027077
# child_sex_ratio                  -0.040648
# effective_literacy_rate_total     0.448006
# effective_literacy_rate_male      0.381888
# effective_literacy_rate_female    0.470812
# total_graduates                   0.197416
# male_graduates                    0.201101
# female_graduates                  0.192372
# Grad_%                            0.969963
# M_Pop                            -0.030456
# F_Pop                             0.030456
# Child_Pop                        -0.378248
# FGrad_Perc                        0.868567
# Literate_Perc                     0.470453
# Literate_MP                       0.432856
# Literate_FP                       0.481588
# Literacy_Gap                     -0.377632
# GradGap                           0.434308

# %%
##M vs W

# %%
plt.plot(df.Child_Pop, df.Literate_MP, 'o')
plt.plot(df.Child_Pop, df.Literate_FP, 'o')
plt.legend(['Males','Females'])
plt.xlabel('Child Population')
plt.ylabel('Literacy %')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
females_df = pd.DataFrame()
males_df = pd.DataFrame()

females_df['Gender'] = np.ones(len(df))
males_df['Gender'] = np.zeros(len(df))

females_df['Literacy_Percentage'] = df.Literate_FP
males_df['Literacy_Percentage'] = df.Literate_MP

females_df['F_share'] = df.F_Pop
males_df['F_share'] = df.F_Pop

females_df['non_weighted_all_weekly'] = df['Literate_Perc']
males_df['non_weighted_all_weekly'] = df['Literate_Perc']

regression_df = males_df.append(females_df)

model = LinearRegression()
columns = ['F_share','Gender','non_weighted_all_weekly']
X = regression_df[columns]

X_std = StandardScaler().fit_transform(X)
y = regression_df['Literacy_Percentage']

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=42)

model.fit(X_train,y_train)

plt.barh([0,1,2],model.coef_)
plt.yticks(range(3),['Share of women','Gender','Literacy Percentage'], fontsize = 10)
plt.title('Regression Coefficients')

print('R^2 on training...',model.score(X_train,y_train))
print('R^2 on test...',model.score(X_test,y_test))
# Out:
# R^2 on training... 0.952587226664
# R^2 on test... 0.963990429873

# %%
model = LinearRegression()
columns = ['Gender']
X = regression_df[columns]

X_std = StandardScaler().fit_transform(X)
y = regression_df['Literacy_Percentage']

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=42)

model.fit(X_train,y_train)

print('R^2 on training...',model.score(X_train,y_train))
print('R^2 on test...',model.score(X_test,y_test))
# Out:
# R^2 on training... 0.280774961494
# R^2 on test... 0.265556609398

# %% [markdown]
# GENDER EXPLAINS 28% OF VARIATION IN LITERACY

# %%
females_df = pd.DataFrame()
males_df = pd.DataFrame()

females_df['Gender'] = np.ones(len(df))
males_df['Gender'] = np.zeros(len(df))

females_df['Graduation_Percentage'] = df.FGrad_Perc
males_df['Graduation_Percentage'] = df.MGrad_Perc

females_df['F_share'] = df.F_Pop
males_df['F_share'] = df.F_Pop

females_df['non_weighted_all_weekly'] = df['Grad_%']
males_df['non_weighted_all_weekly'] = df['Grad_%']

regression_df = males_df.append(females_df)

model = LinearRegression()
columns = ['F_share','Gender','non_weighted_all_weekly']
X = regression_df[columns]

X_std = StandardScaler().fit_transform(X)
y = regression_df['Graduation_Percentage']

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=42)

model.fit(X_train,y_train)

plt.barh([0,1,2],model.coef_)
plt.yticks(range(3),['Share of women','Gender','Graduation Percentage'], fontsize = 10)
plt.title('Regression Coefficients')

print('R^2 on training...',model.score(X_train,y_train))
print('R^2 on test...',model.score(X_test,y_test))
# Out:
# R^2 on training... 0.945369566644
# R^2 on test... 0.940263447757

# %%
model = LinearRegression()
columns = ['Gender']
X = regression_df[columns]

X_std = StandardScaler().fit_transform(X)
y = regression_df['Graduation_Percentage']

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=42)

model.fit(X_train,y_train)

print('R^2 on training...',model.score(X_train,y_train))
print('R^2 on test...',model.score(X_test,y_test))
# Out:
# R^2 on training... 0.183359222504
# R^2 on test... 0.177417956642

# %% [markdown]
# GENDER EXPLAINS 18% OF VARIATION IN GRADUATION

# %%
females_df = pd.DataFrame()
males_df = pd.DataFrame()

females_df['Gender'] = np.ones(len(df))
males_df['Gender'] = np.zeros(len(df))

females_df['Literacy_Percentage'] = df.Literate_FP
males_df['Literacy_Percentage'] = df.Literate_MP

females_df['Child_Pop'] = df.Child_Pop
males_df['Child_Pop'] = df.Child_Pop

females_df['non_weighted_all_weekly'] = df['Literate_Perc']
males_df['non_weighted_all_weekly'] = df['Literate_Perc']

regression_df = males_df.append(females_df)

model = LinearRegression()
columns = ['Child_Pop','Gender','non_weighted_all_weekly']
X = regression_df[columns]

X_std = StandardScaler().fit_transform(X)
y = regression_df['Literacy_Percentage']

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=42)

model.fit(X_train,y_train)

plt.barh([0,1,2],model.coef_)
plt.yticks(range(3),['Child_Pop','Gender','Literacy Percentage'], fontsize = 10)
plt.title('Regression Coefficients')

print('R^2 on training...',model.score(X_train,y_train))
print('R^2 on test...',model.score(X_test,y_test))
# Out:
# R^2 on training... 0.95266528335
# R^2 on test... 0.962555963237

# %%
model = LinearRegression()
columns = ['Child_Pop']
X = regression_df[columns]

X_std = StandardScaler().fit_transform(X)
y = regression_df['Literacy_Percentage']

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=42)

model.fit(X_train,y_train)

print('R^2 on training...',model.score(X_train,y_train))
print('R^2 on test...',model.score(X_test,y_test))
# Out:
# R^2 on training... 0.358114566791
# R^2 on test... 0.400821477243

# %%
model = LinearRegression()
columns = ['Gender']
X = regression_df[columns]

X_std = StandardScaler().fit_transform(X)
y = regression_df['Literacy_Percentage']

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=42)

model.fit(X_train,y_train)

print('R^2 on training...',model.score(X_train,y_train))
print('R^2 on test...',model.score(X_test,y_test))
# Out:
# R^2 on training... 0.280774961494
# R^2 on test... 0.265556609398

# %% [markdown]
# var=['sales','salary']
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# for i in var:
#     df[i]=le.fit_transform(df[i])
#
#
#
#
#
# from sklearn.tree import DecisionTreeClassifier
# clf= DecisionTreeClassifier()
# col=df.columns.drop('left')
# clf.fit(df[col],df['left'])
# imp = clf.feature_importances_
#
#
# lev = pd.DataFrame(col)
# lev['imp']=imp
# lev.sort_values('imp',ascending=False)
#
#
# ##SHOWS RANKING OF FEATURES DETERMINING WHETHER PERSON STAYED OR LEFT

# %%
df.corr()
# Out:
#                                 state_code  dist_code  population_total  \
# state_code                        1.000000  -0.088946          0.054953
# dist_code                        -0.088946   1.000000          0.318398
# population_total                  0.054953   0.318398          1.000000
# population_male                   0.048442   0.319937          0.999647
# population_female                 0.062276   0.316385          0.999547
# 0-6_population_total              0.030726   0.318881          0.991590
# 0-6_population_male               0.025069   0.318189          0.989977
# 0-6_population_female             0.037050   0.319461          0.992786
# literates_total                   0.068414   0.315055          0.998777
# literates_male                    0.060318   0.316732          0.998561
# literates_female                  0.078278   0.312612          0.997831
# sex_ratio                         0.647582  -0.071230         -0.127811
# child_sex_ratio                   0.530039  -0.006449         -0.027147
# effective_literacy_rate_total     0.387393   0.005983          0.079707
# effective_literacy_rate_male      0.386657  -0.003357          0.039787
# effective_literacy_rate_female    0.386275   0.011688          0.100713
# total_graduates                   0.036701   0.322658          0.977282
# male_graduates                    0.038541   0.323013          0.976239
# female_graduates                  0.034332   0.321438          0.976206
# Grad_%                           -0.067473   0.131904          0.144019
# M_Pop                            -0.638151   0.069310          0.129329
# F_Pop                             0.638151  -0.069310         -0.129329
# Child_Pop                        -0.402270   0.029877         -0.047837
# MGrad_Perc                       -0.061744   0.152976          0.114174
# FGrad_Perc                       -0.069078   0.099301          0.166957
# Literate_Perc                     0.425072  -0.005670          0.077672
# Literate_MP                       0.440412  -0.011801          0.051990
# Literate_FP                       0.413880  -0.001453          0.091250
# Literacy_Gap                     -0.210346  -0.016379         -0.121672
# GradGap                           0.001264   0.127455         -0.073629
#
#                                 population_male  population_female  \
# state_code                             0.048442           0.062276
# dist_code                              0.319937           0.316385
# population_total                       0.999647           0.999547
# population_male                        1.000000           0.998395
# population_female                      0.998395           1.000000
# 0-6_population_total                   0.991738           0.990577
# 0-6_population_male                    0.990528           0.988509
# 0-6_population_female                  0.992482           0.992283
# literates_total                        0.998473           0.998270
# literates_male                         0.999003           0.997210
# literates_female                       0.996611           0.998361
# sex_ratio                             -0.139004          -0.115034
# child_sex_ratio                       -0.034290          -0.019040
# effective_literacy_rate_total          0.077046           0.082651
# effective_literacy_rate_male           0.037451           0.042396
# effective_literacy_rate_female         0.097581           0.104171
# total_graduates                        0.974116           0.980032
# male_graduates                         0.972722           0.979389
# female_graduates                       0.973484           0.978455
# Grad_%                                 0.140477           0.147906
# M_Pop                                  0.140764           0.116277
# F_Pop                                 -0.140764          -0.116277
# Child_Pop                             -0.043389          -0.052829
# MGrad_Perc                             0.110860           0.117828
# FGrad_Perc                             0.163411           0.170829
# Literate_Perc                          0.074278           0.081448
# Literate_MP                            0.048850           0.055500
# Literate_FP                            0.087468           0.095453
# Literacy_Gap                          -0.118273          -0.125415
# GradGap                               -0.073854          -0.073312
#
#                                 0-6_population_total  0-6_population_male  \
# state_code                                  0.030726             0.025069
# dist_code                                   0.318881             0.318189
# population_total                            0.991590             0.989977
# population_male                             0.991738             0.990528
# population_female                           0.990577             0.988509
# 0-6_population_total                        1.000000             0.999740
# 0-6_population_male                         0.999740             1.000000
# 0-6_population_female                       0.999673             0.998830
# literates_total                             0.986423             0.984544
# literates_male                              0.987572             0.986181
# literates_female                            0.983815             0.981337
# sex_ratio                                  -0.158482            -0.165095
# child_sex_ratio                            -0.054903            -0.064842
# effective_literacy_rate_total               0.050218             0.048611
# effective_literacy_rate_male                0.016279             0.015208
# effective_literacy_rate_female              0.067407             0.065270
# total_graduates                             0.968286             0.965461
# male_graduates                              0.968568             0.965528
# female_graduates                            0.965591             0.963040
# Grad_%                                      0.122111             0.121284
# M_Pop                                       0.160175             0.166866
# F_Pop                                      -0.160175            -0.166866
# Child_Pop                                   0.010879             0.014058
# MGrad_Perc                                  0.094609             0.093619
# FGrad_Perc                                  0.143993             0.143405
# Literate_Perc                               0.037555             0.035354
# Literate_MP                                 0.013961             0.011917
# Literate_FP                                 0.050246             0.047820
# Literacy_Gap                               -0.091480            -0.089348
# GradGap                                    -0.071275            -0.072197
#
#                                 0-6_population_female  literates_total  \
# state_code                                   0.037050         0.068414
# dist_code                                    0.319461         0.315055
# population_total                             0.992786         0.998777
# population_male                              0.992482         0.998473
# population_female                            0.992283         0.998270
# 0-6_population_total                         0.999673         0.986423
# 0-6_population_male                          0.998830         0.984544
# 0-6_population_female                        1.000000         0.987920
# literates_total                              0.987920         1.000000
# literates_male                               0.988521         0.999557
# literates_female                             0.985984         0.999331
# sex_ratio                                   -0.150968        -0.117465
# child_sex_ratio                             -0.043724        -0.019177
# effective_literacy_rate_total                0.051988         0.105607
# effective_literacy_rate_male                 0.017471         0.065902
# effective_literacy_rate_female               0.069762         0.125006
# total_graduates                              0.970855         0.976203
# male_graduates                               0.971378         0.974338
# female_graduates                             0.967855         0.976149
# Grad_%                                       0.122963         0.152970
# M_Pop                                        0.152572         0.119094
# F_Pop                                       -0.152572        -0.119094
# Child_Pop                                    0.007307        -0.064058
# MGrad_Perc                                   0.095659         0.122082
# FGrad_Perc                                   0.144564         0.176435
# Literate_Perc                                0.040000         0.103472
# Literate_MP                                  0.016243         0.078637
# Literate_FP                                  0.052936         0.115487
# Literacy_Gap                                -0.093815        -0.132561
# GradGap                                     -0.070197        -0.074936
#
#                                 literates_male    ...        M_Pop     F_Pop  \
# state_code                            0.060318    ...    -0.638151  0.638151
# dist_code                             0.316732    ...     0.069310 -0.069310
# population_total                      0.998561    ...     0.129329 -0.129329
# population_male                       0.999003    ...     0.140764 -0.140764
# population_female                     0.997210    ...     0.116277 -0.116277
# 0-6_population_total                  0.987572    ...     0.160175 -0.160175
# 0-6_population_male                   0.986181    ...     0.166866 -0.166866
# 0-6_population_female                 0.988521    ...     0.152572 -0.152572
# literates_total                       0.999557    ...     0.119094 -0.119094
# literates_male                        1.000000    ...     0.132211 -0.132211
# literates_female                      0.997800    ...     0.102833 -0.102833
# sex_ratio                            -0.130386    ...    -0.998809  0.998809
# child_sex_ratio                      -0.028000    ...    -0.627235  0.627235
# effective_literacy_rate_total         0.099151    ...    -0.249401  0.249401
# effective_literacy_rate_male          0.061108    ...    -0.236642  0.236642
# effective_literacy_rate_female        0.117270    ...    -0.281172  0.281172
# total_graduates                       0.972744    ...     0.098396 -0.098396
# male_graduates                        0.970644    ...     0.099645 -0.099645
# female_graduates                      0.972988    ...     0.096611 -0.096611
# Grad_%                                0.146980    ...    -0.049186  0.049186
# M_Pop                                 0.132211    ...     1.000000 -1.000000
# F_Pop                                -0.132211    ...    -1.000000  1.000000
# Child_Pop                            -0.055956    ...     0.489256 -0.489256
# MGrad_Perc                            0.116905    ...    -0.030456  0.030456
# FGrad_Perc                            0.169965    ...    -0.066474  0.066474
# Literate_Perc                         0.095937    ...    -0.337225  0.337225
# Literate_MP                           0.072280    ...    -0.334190  0.334190
# Literate_FP                           0.106983    ...    -0.356306  0.356306
# Literacy_Gap                         -0.123744    ...     0.256127 -0.256127
# GradGap                              -0.073597    ...     0.059515 -0.059515
#
#                                 Child_Pop  MGrad_Perc  FGrad_Perc  \
# state_code                      -0.402270   -0.061744   -0.069078
# dist_code                        0.029877    0.152976    0.099301
# population_total                -0.047837    0.114174    0.166957
# population_male                 -0.043389    0.110860    0.163411
# population_female               -0.052829    0.117828    0.170829
# 0-6_population_total             0.010879    0.094609    0.143993
# 0-6_population_male              0.014058    0.093619    0.143405
# 0-6_population_female            0.007307    0.095659    0.144564
# literates_total                 -0.064058    0.122082    0.176435
# literates_male                  -0.055956    0.116905    0.169965
# literates_female                -0.073936    0.128295    0.184171
# sex_ratio                       -0.492394    0.027077    0.068084
# child_sex_ratio                 -0.371379   -0.040648   -0.060013
# effective_literacy_rate_total   -0.560969    0.448006    0.514532
# effective_literacy_rate_male    -0.446162    0.381888    0.396576
# effective_literacy_rate_female  -0.630553    0.470812    0.572251
# total_graduates                 -0.076775    0.197416    0.241666
# male_graduates                  -0.072895    0.201101    0.235081
# female_graduates                -0.081396    0.192372    0.249238
# Grad_%                          -0.431525    0.969963    0.963027
# M_Pop                            0.489256   -0.030456   -0.066474
# F_Pop                           -0.489256    0.030456    0.066474
# Child_Pop                        1.000000   -0.378248   -0.460219
# MGrad_Perc                      -0.378248    1.000000    0.868567
# FGrad_Perc                      -0.460219    0.868567    1.000000
# Literate_Perc                   -0.728856    0.470453    0.548921
# Literate_MP                     -0.682833    0.432856    0.470291
# Literate_FP                     -0.749039    0.481588    0.588485
# Literacy_Gap                     0.571346   -0.377632   -0.559345
# GradGap                          0.075077    0.434308   -0.069167
#
#                                 Literate_Perc  Literate_MP  Literate_FP  \
# state_code                           0.425072     0.440412     0.413880
# dist_code                           -0.005670    -0.011801    -0.001453
# population_total                     0.077672     0.051990     0.091250
# population_male                      0.074278     0.048850     0.087468
# population_female                    0.081448     0.055500     0.095453
# 0-6_population_total                 0.037555     0.013961     0.050246
# 0-6_population_male                  0.035354     0.011917     0.047820
# 0-6_population_female                0.040000     0.016243     0.052936
# literates_total                      0.103472     0.078637     0.115487
# literates_male                       0.095937     0.072280     0.106983
# literates_female                     0.112605     0.086352     0.125796
# sex_ratio                            0.343344     0.339481     0.362482
# child_sex_ratio                      0.216982     0.195697     0.243467
# effective_literacy_rate_total        0.975363     0.960096     0.948356
# effective_literacy_rate_male         0.905743     0.957192     0.829015
# effective_literacy_rate_female       0.972112     0.907146     0.985809
# total_graduates                      0.109216     0.082083     0.123528
# male_graduates                       0.104253     0.078306     0.117871
# female_graduates                     0.115099     0.086564     0.130235
# Grad_%                               0.525189     0.466155     0.550662
# M_Pop                               -0.337225    -0.334190    -0.356306
# F_Pop                                0.337225     0.334190     0.356306
# Child_Pop                           -0.728856    -0.682833    -0.749039
# MGrad_Perc                           0.470453     0.432856     0.481588
# FGrad_Perc                           0.548921     0.470291     0.588485
# Literate_Perc                        1.000000     0.974215     0.983704
# Literate_MP                          0.974215     1.000000     0.918507
# Literate_FP                          0.983704     0.918507     1.000000
# Literacy_Gap                        -0.621049    -0.429072    -0.751262
# GradGap                             -0.050693     0.016543    -0.100191
#
#                                 Literacy_Gap   GradGap
# state_code                         -0.210346  0.001264
# dist_code                          -0.016379  0.127455
# population_total                   -0.121672 -0.073629
# population_male                    -0.118273 -0.073854
# population_female                  -0.125415 -0.073312
# 0-6_population_total               -0.091480 -0.071275
# 0-6_population_male                -0.089348 -0.072197
# 0-6_population_female              -0.093815 -0.070197
# literates_total                    -0.132561 -0.074936
# literates_male                     -0.123744 -0.073597
# literates_female                   -0.143233 -0.076490
# sex_ratio                          -0.261404 -0.069246
# child_sex_ratio                    -0.229527  0.027256
# effective_literacy_rate_total      -0.563868 -0.033375
# effective_literacy_rate_male       -0.296087  0.047928
# effective_literacy_rate_female     -0.737809 -0.092375
# total_graduates                    -0.145177 -0.041854
# male_graduates                     -0.138559 -0.022466
# female_graduates                   -0.153022 -0.065770
# Grad_%                             -0.479846  0.202150
# M_Pop                               0.256127  0.059515
# F_Pop                              -0.256127 -0.059515
# Child_Pop                           0.571346  0.075077
# MGrad_Perc                         -0.377632  0.434308
# FGrad_Perc                         -0.559345 -0.069167
# Literate_Perc                      -0.621049 -0.050693
# Literate_MP                        -0.429072  0.016543
# Literate_FP                        -0.751262 -0.100191
# Literacy_Gap                        1.000000  0.256493
# GradGap                             0.256493  1.000000
#
# [30 rows x 30 columns]

# %%
GGap = df['GradGap'].mean()/df['Grad_%'].mean()
GGap
# Out:
# 0.17158283612067537

# %%
df['GradGap'].mean()
# Out:
# 0.02271452990094741

# %%
df['Grad_%'].mean()
# Out:
# 0.13238229658922368

# %%
LGap = df['Literacy_Gap'].mean()/df['Literate_Perc'].mean()
LGap
# Out:
# 0.11270576212663178

# %%
df['Literacy_Gap'].mean()
# Out:
# 0.08572805727428055

# %%
df['Literate_Perc'].mean()
# Out:
# 0.7606359750973501
