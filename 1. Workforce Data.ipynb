# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('inc_occ_gender.csv')

# %%
df.head(10)
# Out:
#                                   Occupation  All_workers All_weekly  \
# 0                            ALL OCCUPATIONS       109080        809
# 1                                 MANAGEMENT        12480       1351
# 2                           Chief executives         1046       2041
# 3            General and operations managers          823       1260
# 4                                Legislators            8         Na
# 5        Advertising and promotions managers           55       1050
# 6               Marketing and sales managers          948       1462
# 7  Public relations and fundraising managers           59       1557
# 8           Administrative services managers          170       1191
# 9  Computer and information systems managers          636       1728
#
#    M_workers M_weekly  F_workers F_weekly
# 0      60746      895      48334      726
# 1       7332     1486       5147     1139
# 2        763     2251        283     1836
# ...

# %%
df.describe()
# Out:
#          All_workers     M_workers     F_workers
# count     558.000000    558.000000    558.000000
# mean      586.458781    326.593190    259.831541
# std      4758.979138   2654.600532   2142.551053
# min         0.000000      0.000000      0.000000
# 25%        21.000000     11.000000      3.000000
# 50%        67.000000     33.500000     18.000000
# 75%       253.000000    121.750000     84.000000
# max    109080.000000  60746.000000  48334.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 7 columns):
# Occupation     558 non-null object
# All_workers    558 non-null int64
# All_weekly     558 non-null object
# M_workers      558 non-null int64
# M_weekly       558 non-null object
# F_workers      558 non-null int64
# F_weekly       558 non-null object
# dtypes: int64(3), object(4)
# memory usage: 30.6+ KB

# %%
##ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
df.sort_values('All_workers', ascending = True).head(5)
# Out:
#                                             Occupation  All_workers  \
# 486  Extruding and forming machine setters, operato...            0
# 555                         Mine shuttle car operators            0
# 492               Model makers and patternmakers, wood            0
# 357                               Hunters and trappers            0
# 376                                       Paperhangers            0
#
#     All_weekly  M_workers M_weekly  F_workers F_weekly
# 486         Na          0       Na          0       Na
# 555         Na          0       Na          0       Na
# 492         Na          0       Na          0       Na
# 357         Na          0       Na          0       Na
# 376         Na          0       Na          0       Na

# %%
df1 = df.iloc[1:]

# %%
df1.sort_values('All_workers', ascending = False).head(5).reset_index(drop=True)
# Out:
#        Occupation  All_workers All_weekly  M_workers M_weekly  F_workers  \
# 0          OFFICE        13894        656       3961      693       9933
# 1      MANAGEMENT        12480       1351       7332     1486       5147
# 2           SALES         9725        716       5423      880       4303
# 3      PRODUCTION         7551        663       5548      729       2003
# 4  TRANSPORTATION         6953        646       5998      679        955
#
#   F_weekly
# 0      646
# 1     1139
# 2      578
# 3      519
# 4      494

# %%
df1 = df1[df1.All_weekly != 'Na']

# %%
df2 = df1[df1.M_weekly != 'Na']
df3 = df2[df2.F_weekly != 'Na']

# %%
df3['M_weekly'].mean()
# Out:
# inf

# %%
df3.dtypes
# Out:
# Occupation     object
# All_workers     int64
# All_weekly     object
# M_workers       int64
# M_weekly       object
# F_workers       int64
# F_weekly       object
# dtype: object

# %%
df3['All_weekly'].apply(lambda x: pd.to_numeric(x)).head(3)
# Out:
# 1    1351
# 2    2041
# 3    1260
# Name: All_weekly, dtype: int64

# %%
df3['M_weekly'].apply(lambda x: pd.to_numeric(x)).head(3)
# Out:
# 1    1486
# 2    2251
# 3    1347
# Name: M_weekly, dtype: int64

# %%
df3['F_weekly'].apply(lambda x: pd.to_numeric(x)).head(3)
# Out:
# 1    1139
# 2    1836
# 3    1002
# Name: F_weekly, dtype: int64

# %%
df3.sort_values('All_weekly', ascending = False).head(3)
# Out:
#                               Occupation  All_workers All_weekly  M_workers  \
# 57   Credit counselors and loan officers          313        997        146
# 153                            Designers          593        993        301
# 24                      Lodging managers          123        985         54
#
#     M_weekly  F_workers F_weekly
# 57      1186        166      906
# 153     1099        291      918
# 24      1171         68      902

# %%
df2.iloc[0]
# Out:
# Occupation     MANAGEMENT
# All_workers         12480
# All_weekly           1351
# M_workers            7332
# M_weekly             1486
# F_workers            5147
# F_weekly             1139
# Name: 1, dtype: object

# %%
df2[pd.isnull(df2).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Occupation, All_workers, All_weekly, M_workers, M_weekly, F_workers, F_weekly]
# Index: []

# %%
df.head(3)
# Out:
#          Occupation  All_workers All_weekly  M_workers M_weekly  F_workers  \
# 0   ALL OCCUPATIONS       109080        809      60746      895      48334
# 1        MANAGEMENT        12480       1351       7332     1486       5147
# 2  Chief executives         1046       2041        763     2251        283
#
#   F_weekly
# 0      726
# 1     1139
# 2     1836

# %%
sns.heatmap(df.isnull(), yticklabels = False, cbar = False)

# %%
dff = df[df.M_weekly != 'Na']

# %%
dff1 = dff[dff.F_weekly != 'Na']

# %%
dff1 = dff1[1:]
dff1.head(3)
# Out:
#                         Occupation  All_workers All_weekly  M_workers  \
# 1                       MANAGEMENT        12480       1351       7332
# 2                 Chief executives         1046       2041        763
# 3  General and operations managers          823       1260        621
#
#   M_weekly  F_workers F_weekly
# 1     1486       5147     1139
# 2     2251        283     1836
# 3     1347        202     1002

# %%
dff2 = dff1.apply(pd.to_numeric, errors = 'ignore')
dff2.head(3)
# Out:
#                         Occupation  All_workers  All_weekly  M_workers  \
# 1                       MANAGEMENT        12480        1351       7332
# 2                 Chief executives         1046        2041        763
# 3  General and operations managers          823        1260        621
#
#    M_weekly  F_workers  F_weekly
# 1      1486       5147      1139
# 2      2251        283      1836
# 3      1347        202      1002

# %%
dff2['All_weekly'].mean()
# Out:
# 921.8936170212766

# %%
dff2['M_weekly'].mean()
# Out:
# 1018.4042553191489

# %%
dff2['F_weekly'].mean()
# Out:
# 828.1914893617021

# %%
Overall_Wage_Gap_Avg = dff2['M_weekly'].mean() - dff2['F_weekly'].mean()
Overall_Wage_Gap_Avg
# Out:
# 190.21276595744678

# %%
dff2['Gap'] = dff2['M_weekly'] - dff2['F_weekly']

# %%
dff2.head(3)
# Out:
#                         Occupation  All_workers  All_weekly  M_workers  \
# 1                       MANAGEMENT        12480        1351       7332
# 2                 Chief executives         1046        2041        763
# 3  General and operations managers          823        1260        621
#
#    M_weekly  F_workers  F_weekly  Gap
# 1      1486       5147      1139  347
# 2      2251        283      1836  415
# 3      1347        202      1002  345

# %%
##sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()] #['EmployeeName']

# %%
dff2[dff2['Gap'] == dff2['Gap'].max()]#['Occupation']
# Out:
#     Occupation  All_workers  All_weekly  M_workers  M_weekly  F_workers  \
# 133      LEGAL         1346        1391        624      1877        722
#
#      F_weekly  Gap
# 133      1135  742

# %%
dff2[dff2['Gap'] == dff2['Gap'].min()]#['Occupation']
# Out:
#                                            Occupation  All_workers  \
# 35  Wholesale and retail buyers, except farm products          142
#
#     All_weekly  M_workers  M_weekly  F_workers  F_weekly  Gap
# 35         926         73       886         69       985  -99

# %%
dff2[dff2['Gap'] < 0].count()['Occupation']
# Out:
# 5

# %%
dff2[dff2['Gap'] < 0]
# Out:
#                                             Occupation  All_workers  \
# 35   Wholesale and retail buyers, except farm products          142
# 228               Police and sheriff's patrol officers          655
# 304       Bookkeeping, accounting, and auditing clerks          769
# 340                                  Data entry keyers          223
# 345                             Office clerks, general          929
#
#      All_weekly  M_workers  M_weekly  F_workers  F_weekly  Gap
# 35          926         73       886         69       985  -99
# 228        1002        569      1001         86      1009   -8
# 304         692         87       690        682       692   -2
# 340         619         55       589        169       638  -49
# 345         620        156       609        773       622  -13

# %%
dff2[dff2['Gap'] > 100].count()['Occupation']
# Out:
# 96

# %%
dff2[dff2['Gap'] < 10]
# Out:
#                                             Occupation  All_workers  \
# 35   Wholesale and retail buyers, except farm products          142
# 125                                         Counselors          635
# 228               Police and sheriff's patrol officers          655
# 304       Bookkeeping, accounting, and auditing clerks          769
# 340                                  Data entry keyers          223
# 345                             Office clerks, general          929
#
#      All_weekly  M_workers  M_weekly  F_workers  F_weekly  Gap
# 35          926         73       886         69       985  -99
# 125         904        184       908        451       902    6
# 228        1002        569      1001         86      1009   -8
# 304         692         87       690        682       692   -2
# 340         619         55       589        169       638  -49
# 345         620        156       609        773       622  -13

# %%
dff2 = dff2.reset_index(drop = True)

# %%
dff2.head(10)
# Out:
#                 Occupation  All_workers  All_weekly  M_workers  M_weekly  \
# 0                   OFFICE        13894         656       3961       693
# 1               MANAGEMENT        12480        1351       7332      1486
# 2                    SALES         9725         716       5423       880
# 3               PRODUCTION         7551         663       5548       729
# 4           TRANSPORTATION         6953         646       5998       679
# 5                EDUCATION         6884         956       1849      1144
# 6  HEALTHCARE PROFESSIONAL         6566        1041       1639      1272
# 7                 BUSINESS         5942        1137       2686      1327
# 8             CONSTRUCTION         5722         749       5586       751
# 9              MAINTENANCE         4301         839       4159       842
#
#    F_workers  F_weekly  Gap
# 0       9933       646   47
# 1       5147      1139  347
# 2       4303       578  302
# 3       2003       519  210
# ...

# %%
dff2 = dff2.sort_values('All_workers', ascending=False)
dff2 = dff2.reset_index(drop=True)
dff2.head(3)
# Out:
#    Occupation  All_workers  All_weekly  M_workers  M_weekly  F_workers  \
# 0      OFFICE        13894         656       3961       693       9933
# 1  MANAGEMENT        12480        1351       7332      1486       5147
# 2       SALES         9725         716       5423       880       4303
#
#    F_weekly  Gap
# 0       646   47
# 1      1139  347
# 2       578  302

# %%
#df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

#df2.plot.bar();

# %%
dff5 = dff2.iloc[:10]

# %%
plt.figure()
Visual = pd.DataFrame(dff5, columns = ['M_weekly', 'F_weekly'])
Visual.plot.bar()

# %%
dff2.iloc[:10]['Gap'].mean()
# Out:
# 206.0

# %%
dff2['Gap'].mean()
# Out:
# 190.2127659574468

# %%
sns.pairplot(dff2)

# %%
dff2[['M_weekly', 'F_weekly']].corr()
# Out:
#           M_weekly  F_weekly
# M_weekly  1.000000  0.946166
# F_weekly  0.946166  1.000000

# %%
data1 = dff2[['M_weekly', 'Gap']]
data1.corr()
# Out:
#           M_weekly       Gap
# M_weekly  1.000000  0.713016
# Gap       0.713016  1.000000

# %%
dff2.columns
# Out:
# Index(['Occupation', 'All_workers', 'All_weekly', 'M_workers', 'M_weekly',
#        'F_workers', 'F_weekly', 'Gap'],
#       dtype='object')

# %%
dff2.head(3)
# Out:
#    Occupation  All_workers  All_weekly  M_workers  M_weekly  F_workers  \
# 0      OFFICE        13894         656       3961       693       9933
# 1  MANAGEMENT        12480        1351       7332      1486       5147
# 2       SALES         9725         716       5423       880       4303
#
#    F_weekly  Gap
# 0       646   47
# 1      1139  347
# 2       578  302

# %%
focus_cols = ['Gap']
dff2.corr().filter(focus_cols).drop(focus_cols)
# Out:
#                   Gap
# All_workers  0.007424
# All_weekly   0.594926
# M_workers    0.026126
# M_weekly     0.713016
# F_workers   -0.013733
# F_weekly     0.447683

# %%
focus_cols = ['All_weekly']
dff2.corr().filter(focus_cols).drop(focus_cols)
# Out:
#              All_weekly
# All_workers   -0.049405
# M_workers     -0.018104
# M_weekly       0.982830
# F_workers     -0.069924
# F_weekly       0.978784
# Gap            0.594926

# %%
focus_cols = ['M_weekly']
dff2.corr().filter(focus_cols).drop(focus_cols)
# Out:
#              M_weekly
# All_workers -0.046010
# All_weekly   0.982830
# M_workers   -0.034290
# F_workers   -0.047105
# F_weekly     0.946166
# Gap          0.713016

# %%
##df = df[(df['closing_price'] >= 99) & (df['closing_price'] <= 101)]

# %%
dff3 = dff2[(dff2['Gap'] >= -10) & (dff2['Gap'] <= 10)]

# %%
dff3
# Out:
#                                       Occupation  All_workers  All_weekly  \
# 56  Bookkeeping, accounting, and auditing clerks          769         692
# 63          Police and sheriff's patrol officers          655        1002
# 65                                    Counselors          635         904
#
#     M_workers  M_weekly  F_workers  F_weekly  Gap
# 56         87       690        682       692   -2
# 63        569      1001         86      1009   -8
# 65        184       908        451       902    6

# %%
sns.distplot(dff2['M_weekly'])

# %%
sns.distplot(dff2['Gap'])

# %%
sns.jointplot(x='F_weekly',y='Gap',data=dff2,kind='reg')

# %%
sns.jointplot(x='F_weekly',y='Gap',data=dff2,kind='kde')

# %%
sns.boxplot(x="M_weekly", y="Gap", data=dff2, palette="coolwarm")

# %%
dff2.head()
# Out:
#        Occupation  All_workers  All_weekly  M_workers  M_weekly  F_workers  \
# 0          OFFICE        13894         656       3961       693       9933
# 1      MANAGEMENT        12480        1351       7332      1486       5147
# 2           SALES         9725         716       5423       880       4303
# 3      PRODUCTION         7551         663       5548       729       2003
# 4  TRANSPORTATION         6953         646       5998       679        955
#
#    F_weekly  Gap
# 0       646   47
# 1      1139  347
# 2       578  302
# 3       519  210
# 4       494  185

# %%
dff2['%_Gap'] = dff2['Gap']/(dff2['All_weekly']-dff2['Gap'])

# %%
dff2.head()
# Out:
#        Occupation  All_workers  All_weekly  M_workers  M_weekly  F_workers  \
# 0          OFFICE        13894         656       3961       693       9933
# 1      MANAGEMENT        12480        1351       7332      1486       5147
# 2           SALES         9725         716       5423       880       4303
# 3      PRODUCTION         7551         663       5548       729       2003
# 4  TRANSPORTATION         6953         646       5998       679        955
#
#    F_weekly  Gap     %_Gap
# 0       646   47  0.077176
# 1      1139  347  0.345618
# 2       578  302  0.729469
# 3       519  210  0.463576
# 4       494  185  0.401302

# %%
dff4 = dff2.sort_values('%_Gap', ascending = True)
dff4.reset_index(drop = True).head()
# Out:
#                                           Occupation  All_workers  All_weekly  \
# 0  Wholesale and retail buyers, except farm products          142         926
# 1                                  Data entry keyers          223         619
# 2                             Office clerks, general          929         620
# 3               Police and sheriff's patrol officers          655        1002
# 4       Bookkeeping, accounting, and auditing clerks          769         692
#
#    M_workers  M_weekly  F_workers  F_weekly  Gap     %_Gap
# 0         73       886         69       985  -99 -0.096585
# 1         55       589        169       638  -49 -0.073353
# 2        156       609        773       622  -13 -0.020537
# 3        569      1001         86      1009   -8 -0.007921
# 4         87       690        682       692   -2 -0.002882

# %%
sns.pairplot(dff4)

# %%
focus_col = ['%_Gap']
dff4.corr().filter(focus_col).drop(focus_col)
# Out:
#                 %_Gap
# All_workers  0.029347
# All_weekly   0.182871
# M_workers    0.046913
# M_weekly     0.330664
# F_workers    0.004112
# F_weekly     0.022202
# Gap          0.865390

# %%
sns.distplot(dff4['%_Gap'])

# %%
dff4['%_Gap'].mean()
# Out:
# 0.2795602664458218

# %%
sns.jointplot(x='All_weekly',y='%_Gap',data=dff4,kind='reg')

# %%
dff4[dff4['All_weekly']==dff4['All_weekly'].max()]
# Out:
#           Occupation  All_workers  All_weekly  M_workers  M_weekly  F_workers  \
# 40  Chief executives         1046        2041        763      2251        283
#
#     F_weekly  Gap     %_Gap
# 40      1836  415  0.255228
